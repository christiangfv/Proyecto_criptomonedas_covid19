# %%
import pandas

df = pandas.read_csv('dataset_covid19.csv')

# %%
fecha=pandas.to_datetime(data_covid["newDate"])

datetime_index = pandas.DatetimeIndex(fecha.values) 
data_covid = df.set_index(datetime_index)
data_covid = data_covid.drop(columns=["newDate"])
df
# Out:
#           newDate  cases  deaths countriesAndTerritories geoId  \
# 0      2020-07-14      4       2             Afghanistan    AF
# 1      2020-07-13      0       0             Afghanistan    AF
# 2      2020-07-12     85      16             Afghanistan    AF
# 3      2020-07-11    458      37             Afghanistan    AF
# 4      2020-07-10    255      20             Afghanistan    AF
# ...           ...    ...     ...                     ...   ...
# 29708  2020-03-25      0       0                Zimbabwe    ZW
# 29709  2020-03-24      0       1                Zimbabwe    ZW
# 29710  2020-03-23      0       0                Zimbabwe    ZW
# 29711  2020-03-22      1       0                Zimbabwe    ZW
# 29712  2020-03-21      1       0                Zimbabwe    ZW
#
#       countryterritoryCode  popData2019 continentExp  \
# 0                      AFG   38041757.0         Asia
# 1                      AFG   38041757.0         Asia
# ...
